# %%
def change(num):
  deno = [10,5,3,2,1]
  result=[]
  for i in deno:
    while(i <= num):
      num -= i
      result.append(i)
  print("Left :- ",num)
  return result

# %%
print(change(19))
# Out:
# Left :-  0
# [10, 5, 3, 1]
