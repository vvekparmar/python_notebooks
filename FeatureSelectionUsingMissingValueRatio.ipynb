# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read csv file
data = pd.read_csv("/content/melbourne-housing-market.csv")
data.head()
# Out:
#        Suburb             Address  ...             Regionname Propertycount
# 0  Abbotsford       68 Studley St  ...  Northern Metropolitan        4019.0
# 1  Abbotsford        85 Turner St  ...  Northern Metropolitan        4019.0
# 2  Abbotsford     25 Bloomburg St  ...  Northern Metropolitan        4019.0
# 3  Abbotsford  18/659 Victoria St  ...  Northern Metropolitan        4019.0
# 4  Abbotsford        5 Charles St  ...  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (34857, 21)

# %%
# finding missing values & summation of each coln
empty_coln_cells = data.isnull().sum().sort_values(ascending=False)
empty_coln_cells.head()
# Out:
# BuildingArea    21115
# YearBuilt       19306
# Landsize        11810
# Car              8728
# Bathroom         8226
# dtype: int64

# %%
# missing values percentage for each coln
(data.isnull().sum() / data.shape[0]).sort_values(ascending=False)
# Out:
# BuildingArea     0.605761
# YearBuilt        0.553863
# Landsize         0.338813
# Car              0.250394
# Bathroom         0.235993
# Bedroom2         0.235735
# Longtitude       0.228821
# Lattitude        0.228821
# Price            0.218321
# Regionname       0.000086
# Propertycount    0.000086
# CouncilArea      0.000086
# Postcode         0.000029
# Distance         0.000029
# Date             0.000000
# SellerG          0.000000
# Method           0.000000
# Type             0.000000
# Rooms            0.000000
# Address          0.000000
# Suburb           0.000000
# dtype: float64

# %%
# select important features from the whole data
data[['BuildingArea', 'YearBuilt', 'CouncilArea', 'Car']].head()
# Out:
#    BuildingArea  YearBuilt         CouncilArea  Car
# 0           NaN        NaN  Yarra City Council  1.0
# 1           NaN        NaN  Yarra City Council  1.0
# 2          79.0     1900.0  Yarra City Council  0.0
# 3           NaN        NaN  Yarra City Council  1.0
# 4         150.0     1900.0  Yarra City Council  0.0

# %%
# print missing values of the selected features 
data[['BuildingArea', 'YearBuilt', 'CouncilArea', 'Car']].isnull().sum()
# Out:
# BuildingArea    21115
# YearBuilt       19306
# CouncilArea         3
# Car              8728
# dtype: int64

# %%
# statistics of features
data[['BuildingArea', 'YearBuilt', 'CouncilArea', 'Car']].describe()
# Out:
#        BuildingArea     YearBuilt           Car
# count   13742.00000  15551.000000  26129.000000
# mean      160.25640   1965.289885      1.728845
# std       401.26706     37.328178      1.010771
# min         0.00000   1196.000000      0.000000
# 25%       102.00000   1940.000000      1.000000
# 50%       136.00000   1970.000000      2.000000
# 75%       188.00000   2000.000000      2.000000
# max     44515.00000   2106.000000     26.000000

# %%
# filling missing values with median.
data['Car'] = data['Car'].fillna(data['Car'].median())

# %%
# stats after filling values of 'Car'
data[['BuildingArea', 'YearBuilt', 'CouncilArea', 'Car']].describe()
# Out:
#        BuildingArea     YearBuilt           Car
# count   13742.00000  15551.000000  34857.000000
# mean      160.25640   1965.289885      1.796741
# std       401.26706     37.328178      0.882969
# min         0.00000   1196.000000      0.000000
# 25%       102.00000   1940.000000      1.000000
# 50%       136.00000   1970.000000      2.000000
# 75%       188.00000   2000.000000      2.000000
# max     44515.00000   2106.000000     26.000000

# %%
# finding mode for 'CouncilArea'
data['CouncilArea'].mode()
# Out:
# 0    Boroondara City Council
# dtype: object

# %%
# filling missing values with mode.
data['CouncilArea'] = data['CouncilArea'].fillna(data['CouncilArea'].mode()[0])

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
data.dropna(thresh=int(data.shape[0] * .9), axis=1, inplace=True) # if column has more than 10% of missing values are dropped

# %%
data.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Car              0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
# filling missing values with median.
data['Distance'] = data['Distance'].fillna(data['Distance'].median())

# %%
# filling missing values with median.
data['Postcode'] = data['Postcode'].fillna(data['Postcode'].median())

# %%
# filling missing values with mode.
data['Regionname'] = data['Regionname'].fillna(data['Regionname'].mode()[0])

# %%
# filling missing values with median.
data['Propertycount'] = data['Propertycount'].fillna(data['Propertycount'].median())

# %%
data.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Car              0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
data.to_csv('melb_data.csv', index = False)
